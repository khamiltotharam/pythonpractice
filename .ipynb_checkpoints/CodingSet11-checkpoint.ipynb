# %% [markdown]
# # Chapter **11** Coding Set
#
# **Remember to save a copy of this template BEFORE YOU START WORKING :)**
#
# Work completed by Khamil Totharam.
#
# IMPORTANT: Remember to screen record ALL of your work on at least one problem. You must turn off the generative AI code-completion for this problem, as this problem is preparation for our final exam practical. You can turn off generative AI code-completion within Colab by tapping/clicking the settings icon in the upper right, tapping/clicking the AI Assistance section, and then deselecting "Consented to use generative AI features" and selecting "Hide generative AI features" (these settings may be returned to their previous states once you've completed this problem).
#
# If you start to struggle with a problem for an extended period of time, remember you can go comment on two other submissions now (seeing other student work helps), or you can post in our discussion forum for questions, which can also earn you extra credit.

# %% [markdown]
# ## Imports
#
# **If your program requires additional modules, external resources, or files, use this cell to set them up**

# %%
# configure your environment

# you can uncomment this code to make use of files stored in your Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# you can uncomment the following line of code to use the pandas library
# import pandas as pd

# %% [markdown]
# ### Problem **1**
#
# #### Question Text - Employee and ProductionWorker Classes
#
# ![image.png](attachment:04298850-f32c-4ef5-853d-7ec8419bdd36.png)
# ![image.png](attachment:b12f892f-f84a-468b-82a1-970a43e3602c.png)
#
# #### High-Level Overview
#
# First I created/initialized an employee class and defined getters/setters. Next, I made a production worker subclass with getters/setters. Lastly I created the main function which instanced the subclass and displayed the results from input using the getter methods.

# %%
# define Employee class
class Employee:
    # initialize name and employee number
    def __init__(self, name, employee_number):
        self.__name = name
        self.__employee_number = employee_number
    # define setters    
    def set_name(self, name):
        self.__name = name
    def set_employee_number(self, employee_number):
        self.__employee_number = employee_number
    # define getters
    def get_name(self):
        return self.__name
    def get_employee_number(self):
        return self.__employee_number
# define ProductionWorker class
class ProductionWorker(Employee):
    # initialize parent class and new variables
    def __init__(self, name, employee_number, shift_number, hourly_pay):
        super().__init__(name, employee_number)
        self.__shift_number = shift_number
        self.__hourly_pay = hourly_pay
    # define setters
    def set_shift_number(self, shift_number):
        self.__shift_number = shift_number
    def set_hourly_pay(self, hourly_pay):
        self.__hourly_pay = hourly_pay
    # define getters
    def get_shift_number(self):
        return self.__shift_number
    def get_hourly_pay(self):
        return self.__hourly_pay
# define main function
def main():
    # prompt user
    name = input("Enter the employee name:\n")
    employee_number = input("Employee number:\n")
    # create boolean values for valid shift/pay
    valid_shift = False
    valid_pay = False
    # while loop to check shift input
    while not valid_shift:
        try:
            shift_number = int(input("Shift number: 1 is Day, 2 is Night\n"))
            if shift_number not in (1, 2):
                print("Invalid number...")
            else:
                valid_shift = True
        except:
            print("Enter a valid shift number... 1 is day, 2 is Night\n")
            valid_shift = False
    # while loop to check pay input
    while not valid_pay:
        try:
            hourly_pay = float(input("Enter hourly pay:\n"))
            if hourly_pay < 0:
                print("Enter a positive hourly rate of pay...\n")
            else:
                valid_pay = True
        except:
            print("Enter a valid hourly pay.\n")
            valid_pay = False
    # create instance of production worker and display results
    employee = ProductionWorker(name, employee_number, shift_number, hourly_pay)
    print(f"Name: {employee.get_name()}")
    print(f"Employee Number: {employee.get_employee_number()}")
    print(f"Shift: {employee.get_shift_number()}")
    print(f"Hourly Pay: {employee.get_hourly_pay()}")
# call main function    
if __name__ == "__main__":
    main()
# Out:
# Enter the employee name:
#  Tom
# Employee number:
#  12345
# Shift number: 1 is Day, 2 is Night
#  2
# Enter hourly pay:
#  20
# Name: Tom
# Employee Number: 12345
# Shift: 2
# Hourly Pay: 20.0

# %% [markdown]
# ### Problem **2**
#
# #### Question Text - ShiftSupervisor Class
#
# ![image.png](attachment:34b9a83c-e885-404c-943e-92fd8380ef7e.png)
#
# #### High-Level Overview
#
# First I created the shift supervisor subclass of Employee class and initialized the variables accordingly. Next, I made the setters/getters of the new attributes. Lastly I made the main function, prompted the user for employee information, created an instance of the subclass and displayed the results using the getter methods.

# %%
# create ShiftSupervisor subclass and initialize new variables
class ShiftSupervisor(Employee):
    def __init__(self, name, employee_number, salary, bonus, goal):
        super().__init__(name, employee_number)
        self.__salary = salary
        self.__bonus = bonus
        self.__goal = goal
    # make setters
    def set_salary(self, salary):
        self.__salary = salary
    def set_bonus(self, bonus):
        self.__bonus = bonus
    def set_goal(self, goal):
        self.__goal = goal
    # make getters
    def get_salary(self):
        return self.__salary
    def get_bonus(self):
        return self.__bonus
    def get_goal(self):
        return self.__goal
# define main function
def main():
    # prompt user for input
    name = input("Enter employee name:\n")
    employee_number = input("Enter employee number:\n")
    salary = float(input("Enter salary:\n"))
    bonus = float(input("Enter bonus if production goal is met:\n"))
    goal = float(input("Enter production:\n"))
    # create instance of subclass
    supervisor = ShiftSupervisor(name, employee_number, salary, bonus, goal)
    # check if production goal is met/exceeded and display information
    if supervisor.get_goal() >= 2000:
        print(f"Name: {supervisor.get_name()}")
        print(f"Number: {supervisor.get_employee_number()}")
        print(f"Total pay: {supervisor.get_salary() + supervisor.get_bonus()}")
    else:
        print(f"Name: {supervisor.get_name()}")
        print(f"Number: {supervisor.get_employee_number()}")
        print(f"Total pay: {supervisor.get_salary()}")
# call main function
if __name__ == "__main__":
    main()
# Out:
# Enter employee name:
#  Tom
# Enter employee number:
#  12345
# Enter salary:
#  75000
# Enter bonus if production goal is met:
#  5000
# Enter production:
#  2000
# Name: Tom
# Number: 12345
# Total pay: 80000.0

# %% [markdown]
# ## Helpful Checks
#
# 1.   Did you comment every line of code with meaningful information that will help others reading your code?
# 2.   Did you use appropriate names for your variables, functions, and/or classes?
# 3.   Did you include a high-level explanation for each solution?
# 4.   Did you run each cell that includes a final solution so the output is saved and easily viewed by others?
# 5.   Are you sharing an editable link (i.e., Share > Anyone with the link > Editor) if using Colaboratory, or did you make more than ten commits if using GitHub?
# 6.   Did you remember to comment on the submissions of two other students?
# 7.   Did you remember to screen record all of your work for at least one problem while turning off the generative AI features?
# 8.   Did you remember to create a diagram (e.g., UML class diagram, flowchart, or hierarchical diagram) and include the link with your D2L submission?
